# %%
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import BatchNormalization
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Activation
from keras.layers import Dropout
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras.losses import CategoricalCrossentropy
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# %% [markdown]
# <h3>Preparing imaga data generators for learning:</h3>

# %%
image_width = 64
image_height = 64
batch_size = 16
number_of_channels = 1

training_data_directory_path = "training_data"
validation_data_directory_path = "validation_data"

# %%
training_image_data_generator = ImageDataGenerator(
    rescale=1.0/255,
    zoom_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    fill_mode='nearest'
)
validation_image_data_generator = ImageDataGenerator(
    rescale=1.0/255
)

traning_data_generator = training_image_data_generator.flow_from_directory(
    training_data_directory_path,
    target_size=(image_width, image_height),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True,
    color_mode ="grayscale" # FIRST SOLUTION
)
validation_data_generator = validation_image_data_generator.flow_from_directory(
    validation_data_directory_path,
    target_size=(image_width, image_height),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True,
    color_mode ="grayscale" # FIRST SOLUTION
)
# Out:
# Found 300 images belonging to 5 classes.
# Found 202 images belonging to 5 classes.

# %%
class_names = {value: key for key, value in traning_data_generator.class_indices.items()}

print("Classes: ")
for key, value in class_names.items():
    print(f"{key}: {value}")
# Out:
# Classes:
# 0: circle
# 1: elipse
# 2: rectangle
# 3: square
# 4: triangle

# %% [markdown]
# <h3>Plotting the training images:</h3>

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx=0

for i in range(2):
    for j in range(5):
        class_name = class_names[np.argmax(traning_data_generator[0][1][idx])]
        ax[i, j].set_title(f"{class_name}")
        ax[i, j].imshow(traning_data_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx+=1
plt.tight_layout()
plt.suptitle("Sample training images", fontsize=21)
plt.show()

# %% [markdown]
# <h3>Implementing Convolutional Neural Network:</h3>

# %%
cnn_model = Sequential()

# FIRST LAYER
cnn_model.add(Convolution2D(
    filters=128,
    kernel_size=(5, 5),
    padding="valid",
    input_shape=(image_width, image_height, 1)
))
cnn_model.add(Activation(activation='relu'))
cnn_model.add(MaxPooling2D(pool_size=(2, 2)))
cnn_model.add(BatchNormalization())

# SECOND LAYER
cnn_model.add(Convolution2D(
    filters=64,
    kernel_size=(3, 3),
    padding='valid',
    kernel_regularizer=l2(0.00005)
))
cnn_model.add(Activation(activation='relu'))
cnn_model.add(MaxPooling2D(pool_size=(2, 2)))
cnn_model.add(BatchNormalization())

# THIRD LAYER
cnn_model.add(Convolution2D(
    filters=32,
    kernel_size=(3, 3),
    padding='valid',
    kernel_regularizer=l2(0.00005)
))
cnn_model.add(Activation('relu'))
cnn_model.add(MaxPooling2D(pool_size=(2, 2))) 
cnn_model.add(BatchNormalization())

cnn_model.add(Flatten())
cnn_model.add(Dense(units=256, activation='relu'))
cnn_model.add(Dropout(0.5))
cnn_model.add(Dense(units=5, activation='softmax'))

# %%
cnn_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 60, 60, 128)       3328
#
#  activation_22 (Activation)  (None, 60, 60, 128)       0
#
#  max_pooling2d_18 (MaxPooli  (None, 30, 30, 128)       0
#  ng2D)
#
#  batch_normalization_18 (Ba  (None, 30, 30, 128)       512
#  tchNormalization)
#
#  conv2d_19 (Conv2D)          (None, 28, 28, 64)        73792
#
#  activation_23 (Activation)  (None, 28, 28, 64)        0
#
#  max_pooling2d_19 (MaxPooli  (None, 14, 14, 64)        0
#  ng2D)
#
#  batch_normalization_19 (Ba  (None, 14, 14, 64)        256
#  tchNormalization)
#
#  conv2d_20 (Conv2D)          (None, 12, 12, 32)        18464
#
#  activation_24 (Activation)  (None, 12, 12, 32)        0
#
#  max_pooling2d_20 (MaxPooli  (None, 6, 6, 32)          0
#  ng2D)
#
#  batch_normalization_20 (Ba  (None, 6, 6, 32)          128
#  tchNormalization)
#
#  flatten_6 (Flatten)         (None, 1152)              0
#
#  dense_12 (Dense)            (None, 256)               295168
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 392933 (1.50 MB)
# Trainable params: 392485 (1.50 MB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________

# %%
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=np.sqrt(0.1),
    patience=5
)

optimizer = Adam(learning_rate=0.001)

cnn_model.compile(
    optimizer=optimizer,
    loss=CategoricalCrossentropy(),
    metrics=['accuracy']
)

# %% [markdown]
# <h3>Learning model</h3>

# %%
history = cnn_model.fit(
    traning_data_generator,
    epochs=150,
    verbose=2,
    validation_data=validation_data_generator,
    callbacks=[reduce_lr]
)
# Out:
# Epoch 1/150
# 19/19 - 3s - loss: 2.0683 - accuracy: 0.3600 - val_loss: 1.6947 - val_accuracy: 0.2000 - lr: 0.0010 - 3s/epoch - 174ms/step
# Epoch 2/150
# 19/19 - 2s - loss: 1.7328 - accuracy: 0.4567 - val_loss: 2.0900 - val_accuracy: 0.2000 - lr: 0.0010 - 2s/epoch - 103ms/step
# Epoch 3/150
# 19/19 - 2s - loss: 1.6282 - accuracy: 0.4533 - val_loss: 1.9820 - val_accuracy: 0.2000 - lr: 0.0010 - 2s/epoch - 102ms/step
# Epoch 4/150
# 19/19 - 2s - loss: 1.3337 - accuracy: 0.5233 - val_loss: 2.0140 - val_accuracy: 0.2000 - lr: 0.0010 - 2s/epoch - 106ms/step
# Epoch 5/150
# 19/19 - 2s - loss: 1.4208 - accuracy: 0.4900 - val_loss: 2.2970 - val_accuracy: 0.2000 - lr: 0.0010 - 2s/epoch - 102ms/step
# Epoch 6/150
# 19/19 - 2s - loss: 1.1244 - accuracy: 0.5500 - val_loss: 2.3750 - val_accuracy: 0.2050 - lr: 0.0010 - 2s/epoch - 105ms/step
# Epoch 7/150
# 19/19 - 2s - loss: 1.0352 - accuracy: 0.5767 - val_loss: 2.4605 - val_accuracy: 0.1950 - lr: 3.1623e-04 - 2s/epoch - 107ms/step
# Epoch 8/150
# 19/19 - 2s - loss: 0.9097 - accuracy: 0.5867 - val_loss: 2.5008 - val_accuracy: 0.2150 - lr: 3.1623e-04 - 2s/epoch - 103ms/step
# Epoch 9/150
# 19/19 - 2s - loss: 0.8304 - accuracy: 0.6733 - val_loss: 2.5664 - val_accuracy: 0.2650 - lr: 3.1623e-04 - 2s/epoch - 106ms/step
# Epoch 10/150
# 19/19 - 2s - loss: 0.8394 - accuracy: 0.6933 - val_loss: 2.7804 - val_accuracy: 0.3350 - lr: 3.1623e-04 - 2s/epoch - 109ms/step
# Epoch 11/150
# 19/19 - 2s - loss: 0.8314 - accuracy: 0.6467 - val_loss: 2.9416 - val_accuracy: 0.3550 - lr: 3.1623e-04 - 2s/epoch - 119ms/step
# Epoch 12/150
# 19/19 - 2s - loss: 0.7235 - accuracy: 0.7033 - val_loss: 2.9410 - val_accuracy: 0.3550 - lr: 1.0000e-04 - 2s/epoch - 119ms/step
# Epoch 13/150
# 19/19 - 2s - loss: 0.6758 - accuracy: 0.7433 - val_loss: 2.9505 - val_accuracy: 0.3600 - lr: 1.0000e-04 - 2s/epoch - 106ms/step
# Epoch 14/150
# 19/19 - 3s - loss: 0.6936 - accuracy: 0.7333 - val_loss: 2.9387 - val_accuracy: 0.3650 - lr: 1.0000e-04 - 3s/epoch - 135ms/step
# Epoch 15/150
# 19/19 - 2s - loss: 0.7423 - accuracy: 0.7500 - val_loss: 2.8543 - val_accuracy: 0.3550 - lr: 1.0000e-04 - 2s/epoch - 123ms/step
# Epoch 16/150
# 19/19 - 2s - loss: 0.6539 - accuracy: 0.7400 - val_loss: 2.7673 - val_accuracy: 0.3500 - lr: 1.0000e-04 - 2s/epoch - 120ms/step
# Epoch 17/150
# 19/19 - 2s - loss: 0.7128 - accuracy: 0.7400 - val_loss: 2.7155 - val_accuracy: 0.3550 - lr: 3.1623e-05 - 2s/epoch - 111ms/step
# Epoch 18/150
# 19/19 - 2s - loss: 0.7514 - accuracy: 0.7167 - val_loss: 2.7208 - val_accuracy: 0.3600 - lr: 3.1623e-05 - 2s/epoch - 107ms/step
# Epoch 19/150
# 19/19 - 2s - loss: 0.6097 - accuracy: 0.7567 - val_loss: 2.6823 - val_accuracy: 0.3700 - lr: 3.1623e-05 - 2s/epoch - 108ms/step
# Epoch 20/150
# 19/19 - 2s - loss: 0.7155 - accuracy: 0.7300 - val_loss: 2.6128 - val_accuracy: 0.3700 - lr: 3.1623e-05 - 2s/epoch - 116ms/step
# Epoch 21/150
# 19/19 - 2s - loss: 0.6599 - accuracy: 0.7267 - val_loss: 2.5724 - val_accuracy: 0.3650 - lr: 3.1623e-05 - 2s/epoch - 112ms/step
# Epoch 22/150
# 19/19 - 2s - loss: 0.6496 - accuracy: 0.7200 - val_loss: 2.4762 - val_accuracy: 0.3650 - lr: 1.0000e-05 - 2s/epoch - 108ms/step
# Epoch 23/150
# 19/19 - 2s - loss: 0.6932 - accuracy: 0.6867 - val_loss: 2.3711 - val_accuracy: 0.3650 - lr: 1.0000e-05 - 2s/epoch - 103ms/step
# Epoch 24/150
# 19/19 - 2s - loss: 0.7080 - accuracy: 0.7300 - val_loss: 2.2442 - val_accuracy: 0.3650 - lr: 1.0000e-05 - 2s/epoch - 105ms/step
# Epoch 25/150
# 19/19 - 2s - loss: 0.6421 - accuracy: 0.7300 - val_loss: 2.0816 - val_accuracy: 0.3650 - lr: 1.0000e-05 - 2s/epoch - 109ms/step
# Epoch 26/150
# 19/19 - 2s - loss: 0.6740 - accuracy: 0.7367 - val_loss: 1.8684 - val_accuracy: 0.3650 - lr: 1.0000e-05 - 2s/epoch - 108ms/step
# Epoch 27/150
# 19/19 - 2s - loss: 0.6363 - accuracy: 0.7533 - val_loss: 1.6518 - val_accuracy: 0.3850 - lr: 3.1623e-06 - 2s/epoch - 105ms/step
# Epoch 28/150
# 19/19 - 2s - loss: 0.6390 - accuracy: 0.7433 - val_loss: 1.4314 - val_accuracy: 0.4150 - lr: 3.1623e-06 - 2s/epoch - 115ms/step
# Epoch 29/150
# 19/19 - 2s - loss: 0.6503 - accuracy: 0.7333 - val_loss: 1.1917 - val_accuracy: 0.4400 - lr: 3.1623e-06 - 2s/epoch - 108ms/step
# Epoch 30/150
# 19/19 - 2s - loss: 0.6230 - accuracy: 0.7267 - val_loss: 0.9875 - val_accuracy: 0.5050 - lr: 3.1623e-06 - 2s/epoch - 109ms/step
# Epoch 31/150
# 19/19 - 2s - loss: 0.6408 - accuracy: 0.7367 - val_loss: 0.8179 - val_accuracy: 0.6200 - lr: 3.1623e-06 - 2s/epoch - 113ms/step
# Epoch 32/150
# 19/19 - 2s - loss: 0.6600 - accuracy: 0.7167 - val_loss: 0.7004 - val_accuracy: 0.6900 - lr: 3.1623e-06 - 2s/epoch - 107ms/step
# Epoch 33/150
# 19/19 - 2s - loss: 0.6363 - accuracy: 0.7400 - val_loss: 0.5998 - val_accuracy: 0.7400 - lr: 3.1623e-06 - 2s/epoch - 107ms/step
# Epoch 34/150
# 19/19 - 2s - loss: 0.6011 - accuracy: 0.7433 - val_loss: 0.5315 - val_accuracy: 0.7850 - lr: 3.1623e-06 - 2s/epoch - 104ms/step
# Epoch 35/150
# 19/19 - 2s - loss: 0.6050 - accuracy: 0.7800 - val_loss: 0.4821 - val_accuracy: 0.8100 - lr: 3.1623e-06 - 2s/epoch - 105ms/step
# Epoch 36/150
# 19/19 - 2s - loss: 0.5381 - accuracy: 0.7800 - val_loss: 0.4458 - val_accuracy: 0.8400 - lr: 3.1623e-06 - 2s/epoch - 103ms/step
# Epoch 37/150
# 19/19 - 2s - loss: 0.5800 - accuracy: 0.7433 - val_loss: 0.4171 - val_accuracy: 0.8550 - lr: 3.1623e-06 - 2s/epoch - 104ms/step
# Epoch 38/150
# 19/19 - 2s - loss: 0.6203 - accuracy: 0.7467 - val_loss: 0.3984 - val_accuracy: 0.8700 - lr: 3.1623e-06 - 2s/epoch - 108ms/step
# Epoch 39/150
# 19/19 - 2s - loss: 0.6927 - accuracy: 0.7000 - val_loss: 0.3860 - val_accuracy: 0.8900 - lr: 3.1623e-06 - 2s/epoch - 107ms/step
# Epoch 40/150
# 19/19 - 2s - loss: 0.6523 - accuracy: 0.7433 - val_loss: 0.3807 - val_accuracy: 0.9000 - lr: 3.1623e-06 - 2s/epoch - 110ms/step
# Epoch 41/150
# 19/19 - 2s - loss: 0.6708 - accuracy: 0.7300 - val_loss: 0.3825 - val_accuracy: 0.8900 - lr: 3.1623e-06 - 2s/epoch - 117ms/step
# Epoch 42/150
# 19/19 - 2s - loss: 0.7480 - accuracy: 0.6967 - val_loss: 0.3856 - val_accuracy: 0.8650 - lr: 3.1623e-06 - 2s/epoch - 120ms/step
# Epoch 43/150
# 19/19 - 2s - loss: 0.6381 - accuracy: 0.7400 - val_loss: 0.3889 - val_accuracy: 0.8650 - lr: 3.1623e-06 - 2s/epoch - 106ms/step
# Epoch 44/150
# 19/19 - 2s - loss: 0.6605 - accuracy: 0.7467 - val_loss: 0.3979 - val_accuracy: 0.8700 - lr: 3.1623e-06 - 2s/epoch - 106ms/step
# Epoch 45/150
# 19/19 - 2s - loss: 0.5923 - accuracy: 0.7767 - val_loss: 0.4115 - val_accuracy: 0.8700 - lr: 3.1623e-06 - 2s/epoch - 121ms/step
# Epoch 46/150
# 19/19 - 2s - loss: 0.6815 - accuracy: 0.7467 - val_loss: 0.4223 - val_accuracy: 0.8500 - lr: 1.0000e-06 - 2s/epoch - 117ms/step
# Epoch 47/150
# 19/19 - 2s - loss: 0.6064 - accuracy: 0.7667 - val_loss: 0.4375 - val_accuracy: 0.8400 - lr: 1.0000e-06 - 2s/epoch - 114ms/step
# Epoch 48/150
# 19/19 - 2s - loss: 0.6169 - accuracy: 0.7533 - val_loss: 0.4467 - val_accuracy: 0.8250 - lr: 1.0000e-06 - 2s/epoch - 121ms/step
# Epoch 49/150
# 19/19 - 2s - loss: 0.6253 - accuracy: 0.7633 - val_loss: 0.4533 - val_accuracy: 0.8250 - lr: 1.0000e-06 - 2s/epoch - 113ms/step
# Epoch 50/150
# 19/19 - 2s - loss: 0.6717 - accuracy: 0.7467 - val_loss: 0.4532 - val_accuracy: 0.8250 - lr: 1.0000e-06 - 2s/epoch - 107ms/step
# Epoch 51/150
# 19/19 - 2s - loss: 0.7211 - accuracy: 0.7533 - val_loss: 0.4635 - val_accuracy: 0.8150 - lr: 3.1623e-07 - 2s/epoch - 105ms/step
# Epoch 52/150
# 19/19 - 2s - loss: 0.6781 - accuracy: 0.7033 - val_loss: 0.4693 - val_accuracy: 0.8050 - lr: 3.1623e-07 - 2s/epoch - 108ms/step
# Epoch 53/150
# 19/19 - 2s - loss: 0.6151 - accuracy: 0.7900 - val_loss: 0.4736 - val_accuracy: 0.8000 - lr: 3.1623e-07 - 2s/epoch - 112ms/step
# Epoch 54/150
# 19/19 - 2s - loss: 0.6184 - accuracy: 0.7500 - val_loss: 0.4742 - val_accuracy: 0.8000 - lr: 3.1623e-07 - 2s/epoch - 109ms/step
# Epoch 55/150
# 19/19 - 2s - loss: 0.6883 - accuracy: 0.7533 - val_loss: 0.4834 - val_accuracy: 0.7900 - lr: 3.1623e-07 - 2s/epoch - 114ms/step
# Epoch 56/150
# 19/19 - 2s - loss: 0.6017 - accuracy: 0.7633 - val_loss: 0.4838 - val_accuracy: 0.7900 - lr: 1.0000e-07 - 2s/epoch - 120ms/step
# Epoch 57/150
# 19/19 - 2s - loss: 0.6052 - accuracy: 0.7500 - val_loss: 0.4870 - val_accuracy: 0.7900 - lr: 1.0000e-07 - 2s/epoch - 104ms/step
# Epoch 58/150
# 19/19 - 2s - loss: 0.6445 - accuracy: 0.7600 - val_loss: 0.4910 - val_accuracy: 0.7900 - lr: 1.0000e-07 - 2s/epoch - 103ms/step
# Epoch 59/150
# 19/19 - 2s - loss: 0.6660 - accuracy: 0.7433 - val_loss: 0.4915 - val_accuracy: 0.7900 - lr: 1.0000e-07 - 2s/epoch - 103ms/step
# Epoch 60/150
# 19/19 - 2s - loss: 0.6377 - accuracy: 0.7600 - val_loss: 0.4907 - val_accuracy: 0.7900 - lr: 1.0000e-07 - 2s/epoch - 122ms/step
# Epoch 61/150
# 19/19 - 2s - loss: 0.6060 - accuracy: 0.7333 - val_loss: 0.4930 - val_accuracy: 0.7900 - lr: 3.1623e-08 - 2s/epoch - 108ms/step
# Epoch 62/150
# 19/19 - 2s - loss: 0.6588 - accuracy: 0.7367 - val_loss: 0.4891 - val_accuracy: 0.7900 - lr: 3.1623e-08 - 2s/epoch - 121ms/step
# Epoch 63/150
# 19/19 - 2s - loss: 0.7104 - accuracy: 0.7400 - val_loss: 0.4914 - val_accuracy: 0.7900 - lr: 3.1623e-08 - 2s/epoch - 102ms/step
# Epoch 64/150
# 19/19 - 2s - loss: 0.6616 - accuracy: 0.6933 - val_loss: 0.4880 - val_accuracy: 0.7900 - lr: 3.1623e-08 - 2s/epoch - 104ms/step
# Epoch 65/150
# 19/19 - 2s - loss: 0.6556 - accuracy: 0.7500 - val_loss: 0.4867 - val_accuracy: 0.7900 - lr: 3.1623e-08 - 2s/epoch - 114ms/step
# Epoch 66/150
# 19/19 - 2s - loss: 0.6162 - accuracy: 0.7467 - val_loss: 0.4843 - val_accuracy: 0.7900 - lr: 1.0000e-08 - 2s/epoch - 119ms/step
# Epoch 67/150
# 19/19 - 2s - loss: 0.6321 - accuracy: 0.7400 - val_loss: 0.4867 - val_accuracy: 0.7900 - lr: 1.0000e-08 - 2s/epoch - 108ms/step
# Epoch 68/150
# 19/19 - 2s - loss: 0.5962 - accuracy: 0.7667 - val_loss: 0.4892 - val_accuracy: 0.7900 - lr: 1.0000e-08 - 2s/epoch - 106ms/step
# Epoch 69/150
# 19/19 - 2s - loss: 0.6241 - accuracy: 0.7567 - val_loss: 0.4949 - val_accuracy: 0.7900 - lr: 1.0000e-08 - 2s/epoch - 105ms/step
# Epoch 70/150
# 19/19 - 2s - loss: 0.6265 - accuracy: 0.7600 - val_loss: 0.4910 - val_accuracy: 0.7900 - lr: 1.0000e-08 - 2s/epoch - 115ms/step
# Epoch 71/150
# 19/19 - 2s - loss: 0.6009 - accuracy: 0.7533 - val_loss: 0.4880 - val_accuracy: 0.7900 - lr: 3.1623e-09 - 2s/epoch - 102ms/step
# Epoch 72/150
# 19/19 - 2s - loss: 0.7060 - accuracy: 0.7333 - val_loss: 0.4917 - val_accuracy: 0.7850 - lr: 3.1623e-09 - 2s/epoch - 103ms/step
# Epoch 73/150
# 19/19 - 2s - loss: 0.6586 - accuracy: 0.7667 - val_loss: 0.4940 - val_accuracy: 0.7900 - lr: 3.1623e-09 - 2s/epoch - 106ms/step
# Epoch 74/150
# 19/19 - 2s - loss: 0.6803 - accuracy: 0.7533 - val_loss: 0.4934 - val_accuracy: 0.7850 - lr: 3.1623e-09 - 2s/epoch - 112ms/step
# Epoch 75/150
# 19/19 - 2s - loss: 0.6504 - accuracy: 0.7300 - val_loss: 0.4982 - val_accuracy: 0.7850 - lr: 3.1623e-09 - 2s/epoch - 114ms/step
# Epoch 76/150
# 19/19 - 2s - loss: 0.6324 - accuracy: 0.7633 - val_loss: 0.5003 - val_accuracy: 0.7850 - lr: 1.0000e-09 - 2s/epoch - 105ms/step
# Epoch 77/150
# 19/19 - 2s - loss: 0.6287 - accuracy: 0.7267 - val_loss: 0.4971 - val_accuracy: 0.7850 - lr: 1.0000e-09 - 2s/epoch - 110ms/step
# Epoch 78/150
# 19/19 - 2s - loss: 0.5988 - accuracy: 0.7633 - val_loss: 0.4910 - val_accuracy: 0.7900 - lr: 1.0000e-09 - 2s/epoch - 106ms/step
# Epoch 79/150
# 19/19 - 2s - loss: 0.6142 - accuracy: 0.7667 - val_loss: 0.4946 - val_accuracy: 0.7900 - lr: 1.0000e-09 - 2s/epoch - 105ms/step
# Epoch 80/150
# 19/19 - 2s - loss: 0.5864 - accuracy: 0.7900 - val_loss: 0.4901 - val_accuracy: 0.7900 - lr: 1.0000e-09 - 2s/epoch - 105ms/step
# Epoch 81/150
# 19/19 - 2s - loss: 0.7045 - accuracy: 0.7067 - val_loss: 0.4895 - val_accuracy: 0.7900 - lr: 3.1623e-10 - 2s/epoch - 114ms/step
# Epoch 82/150
# 19/19 - 2s - loss: 0.6188 - accuracy: 0.7600 - val_loss: 0.4927 - val_accuracy: 0.7850 - lr: 3.1623e-10 - 2s/epoch - 128ms/step
# Epoch 83/150
# 19/19 - 2s - loss: 0.6722 - accuracy: 0.6933 - val_loss: 0.4919 - val_accuracy: 0.7850 - lr: 3.1623e-10 - 2s/epoch - 106ms/step
# Epoch 84/150
# 19/19 - 2s - loss: 0.6646 - accuracy: 0.7133 - val_loss: 0.4997 - val_accuracy: 0.7850 - lr: 3.1623e-10 - 2s/epoch - 104ms/step
# Epoch 85/150
# 19/19 - 2s - loss: 0.5856 - accuracy: 0.7800 - val_loss: 0.4968 - val_accuracy: 0.7850 - lr: 3.1623e-10 - 2s/epoch - 102ms/step
# Epoch 86/150
# 19/19 - 2s - loss: 0.7336 - accuracy: 0.7100 - val_loss: 0.4941 - val_accuracy: 0.7850 - lr: 1.0000e-10 - 2s/epoch - 106ms/step
# Epoch 87/150
# 19/19 - 2s - loss: 0.5905 - accuracy: 0.7700 - val_loss: 0.4958 - val_accuracy: 0.7850 - lr: 1.0000e-10 - 2s/epoch - 107ms/step
# Epoch 88/150
# 19/19 - 2s - loss: 0.6946 - accuracy: 0.7467 - val_loss: 0.4961 - val_accuracy: 0.7850 - lr: 1.0000e-10 - 2s/epoch - 107ms/step
# Epoch 89/150
# 19/19 - 2s - loss: 0.6577 - accuracy: 0.7200 - val_loss: 0.4952 - val_accuracy: 0.7850 - lr: 1.0000e-10 - 2s/epoch - 112ms/step
# Epoch 90/150
# 19/19 - 2s - loss: 0.6722 - accuracy: 0.7600 - val_loss: 0.4993 - val_accuracy: 0.7850 - lr: 1.0000e-10 - 2s/epoch - 106ms/step
# Epoch 91/150
# 19/19 - 2s - loss: 0.5893 - accuracy: 0.7400 - val_loss: 0.4920 - val_accuracy: 0.7850 - lr: 3.1623e-11 - 2s/epoch - 107ms/step
# Epoch 92/150
# 19/19 - 2s - loss: 0.7613 - accuracy: 0.6967 - val_loss: 0.4960 - val_accuracy: 0.7850 - lr: 3.1623e-11 - 2s/epoch - 110ms/step
# Epoch 93/150
# 19/19 - 2s - loss: 0.6811 - accuracy: 0.7300 - val_loss: 0.4952 - val_accuracy: 0.7850 - lr: 3.1623e-11 - 2s/epoch - 109ms/step
# Epoch 94/150
# 19/19 - 2s - loss: 0.6408 - accuracy: 0.7433 - val_loss: 0.4956 - val_accuracy: 0.7850 - lr: 3.1623e-11 - 2s/epoch - 109ms/step
# Epoch 95/150
# 19/19 - 2s - loss: 0.6608 - accuracy: 0.7333 - val_loss: 0.4941 - val_accuracy: 0.7850 - lr: 3.1623e-11 - 2s/epoch - 114ms/step
# Epoch 96/150
# 19/19 - 2s - loss: 0.6950 - accuracy: 0.7067 - val_loss: 0.4952 - val_accuracy: 0.7850 - lr: 1.0000e-11 - 2s/epoch - 107ms/step
# Epoch 97/150
# 19/19 - 2s - loss: 0.6083 - accuracy: 0.7200 - val_loss: 0.4938 - val_accuracy: 0.7850 - lr: 1.0000e-11 - 2s/epoch - 103ms/step
# Epoch 98/150
# 19/19 - 2s - loss: 0.6209 - accuracy: 0.7567 - val_loss: 0.4945 - val_accuracy: 0.7850 - lr: 1.0000e-11 - 2s/epoch - 108ms/step
# Epoch 99/150
# 19/19 - 2s - loss: 0.5940 - accuracy: 0.7333 - val_loss: 0.4989 - val_accuracy: 0.7850 - lr: 1.0000e-11 - 2s/epoch - 108ms/step
# Epoch 100/150
# 19/19 - 2s - loss: 0.7079 - accuracy: 0.7167 - val_loss: 0.4990 - val_accuracy: 0.7850 - lr: 1.0000e-11 - 2s/epoch - 118ms/step
# Epoch 101/150
# 19/19 - 2s - loss: 0.6643 - accuracy: 0.7400 - val_loss: 0.5019 - val_accuracy: 0.7850 - lr: 3.1623e-12 - 2s/epoch - 119ms/step
# Epoch 102/150
# 19/19 - 2s - loss: 0.6236 - accuracy: 0.7300 - val_loss: 0.4989 - val_accuracy: 0.7850 - lr: 3.1623e-12 - 2s/epoch - 117ms/step
# Epoch 103/150
# 19/19 - 2s - loss: 0.6223 - accuracy: 0.7567 - val_loss: 0.4984 - val_accuracy: 0.7900 - lr: 3.1623e-12 - 2s/epoch - 109ms/step
# Epoch 104/150
# 19/19 - 2s - loss: 0.7014 - accuracy: 0.7300 - val_loss: 0.4993 - val_accuracy: 0.7900 - lr: 3.1623e-12 - 2s/epoch - 104ms/step
# Epoch 105/150
# 19/19 - 2s - loss: 0.6214 - accuracy: 0.7433 - val_loss: 0.4953 - val_accuracy: 0.7850 - lr: 3.1623e-12 - 2s/epoch - 101ms/step
# Epoch 106/150
# 19/19 - 2s - loss: 0.6157 - accuracy: 0.7500 - val_loss: 0.4919 - val_accuracy: 0.7850 - lr: 1.0000e-12 - 2s/epoch - 101ms/step
# Epoch 107/150
# 19/19 - 2s - loss: 0.6840 - accuracy: 0.7167 - val_loss: 0.4922 - val_accuracy: 0.7850 - lr: 1.0000e-12 - 2s/epoch - 105ms/step
# Epoch 108/150
# 19/19 - 2s - loss: 0.6720 - accuracy: 0.7067 - val_loss: 0.4951 - val_accuracy: 0.7900 - lr: 1.0000e-12 - 2s/epoch - 110ms/step
# Epoch 109/150
# 19/19 - 2s - loss: 0.7056 - accuracy: 0.7200 - val_loss: 0.4939 - val_accuracy: 0.7900 - lr: 1.0000e-12 - 2s/epoch - 109ms/step
# Epoch 110/150
# 19/19 - 2s - loss: 0.6224 - accuracy: 0.7300 - val_loss: 0.4931 - val_accuracy: 0.7900 - lr: 1.0000e-12 - 2s/epoch - 104ms/step
# Epoch 111/150
# 19/19 - 2s - loss: 0.6553 - accuracy: 0.7233 - val_loss: 0.4882 - val_accuracy: 0.7900 - lr: 3.1623e-13 - 2s/epoch - 106ms/step
# Epoch 112/150
# 19/19 - 2s - loss: 0.6503 - accuracy: 0.7333 - val_loss: 0.4847 - val_accuracy: 0.7900 - lr: 3.1623e-13 - 2s/epoch - 106ms/step
# Epoch 113/150
# 19/19 - 2s - loss: 0.6253 - accuracy: 0.7267 - val_loss: 0.4863 - val_accuracy: 0.7900 - lr: 3.1623e-13 - 2s/epoch - 104ms/step
# Epoch 114/150
# 19/19 - 2s - loss: 0.5668 - accuracy: 0.7733 - val_loss: 0.4854 - val_accuracy: 0.7900 - lr: 3.1623e-13 - 2s/epoch - 104ms/step
# Epoch 115/150
# 19/19 - 2s - loss: 0.6148 - accuracy: 0.7533 - val_loss: 0.4914 - val_accuracy: 0.7900 - lr: 3.1623e-13 - 2s/epoch - 102ms/step
# Epoch 116/150
# 19/19 - 2s - loss: 0.5116 - accuracy: 0.7833 - val_loss: 0.4928 - val_accuracy: 0.7900 - lr: 1.0000e-13 - 2s/epoch - 103ms/step
# Epoch 117/150
# 19/19 - 2s - loss: 0.6831 - accuracy: 0.7333 - val_loss: 0.4919 - val_accuracy: 0.7850 - lr: 1.0000e-13 - 2s/epoch - 107ms/step
# Epoch 118/150
# 19/19 - 2s - loss: 0.6384 - accuracy: 0.7267 - val_loss: 0.4940 - val_accuracy: 0.7900 - lr: 1.0000e-13 - 2s/epoch - 106ms/step
# Epoch 119/150
# 19/19 - 2s - loss: 0.7012 - accuracy: 0.7400 - val_loss: 0.4907 - val_accuracy: 0.7850 - lr: 1.0000e-13 - 2s/epoch - 106ms/step
# Epoch 120/150
# 19/19 - 2s - loss: 0.7021 - accuracy: 0.7100 - val_loss: 0.4925 - val_accuracy: 0.7900 - lr: 1.0000e-13 - 2s/epoch - 113ms/step
# Epoch 121/150
# 19/19 - 2s - loss: 0.7296 - accuracy: 0.7300 - val_loss: 0.4960 - val_accuracy: 0.7900 - lr: 3.1623e-14 - 2s/epoch - 113ms/step
# Epoch 122/150
# 19/19 - 2s - loss: 0.6164 - accuracy: 0.7467 - val_loss: 0.4986 - val_accuracy: 0.7900 - lr: 3.1623e-14 - 2s/epoch - 115ms/step
# Epoch 123/150
# 19/19 - 2s - loss: 0.6873 - accuracy: 0.7400 - val_loss: 0.5007 - val_accuracy: 0.7900 - lr: 3.1623e-14 - 2s/epoch - 108ms/step
# Epoch 124/150
# 19/19 - 2s - loss: 0.6537 - accuracy: 0.7433 - val_loss: 0.5004 - val_accuracy: 0.7900 - lr: 3.1623e-14 - 2s/epoch - 103ms/step
# Epoch 125/150
# 19/19 - 2s - loss: 0.6847 - accuracy: 0.7200 - val_loss: 0.4987 - val_accuracy: 0.7850 - lr: 3.1623e-14 - 2s/epoch - 104ms/step
# Epoch 126/150
# 19/19 - 2s - loss: 0.5962 - accuracy: 0.7567 - val_loss: 0.4974 - val_accuracy: 0.7900 - lr: 1.0000e-14 - 2s/epoch - 102ms/step
# Epoch 127/150
# 19/19 - 2s - loss: 0.6550 - accuracy: 0.7533 - val_loss: 0.4932 - val_accuracy: 0.7900 - lr: 1.0000e-14 - 2s/epoch - 101ms/step
# Epoch 128/150
# 19/19 - 2s - loss: 0.6267 - accuracy: 0.7567 - val_loss: 0.4962 - val_accuracy: 0.7900 - lr: 1.0000e-14 - 2s/epoch - 103ms/step
# Epoch 129/150
# 19/19 - 2s - loss: 0.6822 - accuracy: 0.7233 - val_loss: 0.4947 - val_accuracy: 0.7900 - lr: 1.0000e-14 - 2s/epoch - 102ms/step
# Epoch 130/150
# 19/19 - 2s - loss: 0.6814 - accuracy: 0.7500 - val_loss: 0.4922 - val_accuracy: 0.7900 - lr: 1.0000e-14 - 2s/epoch - 104ms/step
# Epoch 131/150
# 19/19 - 2s - loss: 0.6782 - accuracy: 0.7400 - val_loss: 0.4963 - val_accuracy: 0.7900 - lr: 3.1623e-15 - 2s/epoch - 101ms/step
# Epoch 132/150
# 19/19 - 2s - loss: 0.6608 - accuracy: 0.7133 - val_loss: 0.4994 - val_accuracy: 0.7850 - lr: 3.1623e-15 - 2s/epoch - 103ms/step
# Epoch 133/150
# 19/19 - 2s - loss: 0.6551 - accuracy: 0.7400 - val_loss: 0.5003 - val_accuracy: 0.7900 - lr: 3.1623e-15 - 2s/epoch - 114ms/step
# Epoch 134/150
# 19/19 - 2s - loss: 0.6401 - accuracy: 0.7600 - val_loss: 0.4969 - val_accuracy: 0.7850 - lr: 3.1623e-15 - 2s/epoch - 106ms/step
# Epoch 135/150
# 19/19 - 2s - loss: 0.5756 - accuracy: 0.7867 - val_loss: 0.4972 - val_accuracy: 0.7850 - lr: 3.1623e-15 - 2s/epoch - 110ms/step
# Epoch 136/150
# 19/19 - 2s - loss: 0.6669 - accuracy: 0.7333 - val_loss: 0.4978 - val_accuracy: 0.7850 - lr: 1.0000e-15 - 2s/epoch - 111ms/step
# Epoch 137/150
# 19/19 - 2s - loss: 0.6042 - accuracy: 0.7467 - val_loss: 0.4979 - val_accuracy: 0.7900 - lr: 1.0000e-15 - 2s/epoch - 104ms/step
# Epoch 138/150
# 19/19 - 2s - loss: 0.6133 - accuracy: 0.7733 - val_loss: 0.4949 - val_accuracy: 0.7850 - lr: 1.0000e-15 - 2s/epoch - 109ms/step
# Epoch 139/150
# 19/19 - 2s - loss: 0.6654 - accuracy: 0.7500 - val_loss: 0.4984 - val_accuracy: 0.7850 - lr: 1.0000e-15 - 2s/epoch - 109ms/step
# Epoch 140/150
# 19/19 - 2s - loss: 0.6524 - accuracy: 0.7233 - val_loss: 0.5027 - val_accuracy: 0.7850 - lr: 1.0000e-15 - 2s/epoch - 105ms/step
# Epoch 141/150
# 19/19 - 2s - loss: 0.6712 - accuracy: 0.7300 - val_loss: 0.4940 - val_accuracy: 0.7850 - lr: 3.1623e-16 - 2s/epoch - 106ms/step
# Epoch 142/150
# 19/19 - 2s - loss: 0.5884 - accuracy: 0.7667 - val_loss: 0.4932 - val_accuracy: 0.7850 - lr: 3.1623e-16 - 2s/epoch - 106ms/step
# Epoch 143/150
# 19/19 - 2s - loss: 0.7584 - accuracy: 0.7267 - val_loss: 0.4944 - val_accuracy: 0.7850 - lr: 3.1623e-16 - 2s/epoch - 101ms/step
# Epoch 144/150
# 19/19 - 2s - loss: 0.7002 - accuracy: 0.7500 - val_loss: 0.4975 - val_accuracy: 0.7850 - lr: 3.1623e-16 - 2s/epoch - 101ms/step
# Epoch 145/150
# 19/19 - 2s - loss: 0.5941 - accuracy: 0.7400 - val_loss: 0.4963 - val_accuracy: 0.7850 - lr: 3.1623e-16 - 2s/epoch - 102ms/step
# Epoch 146/150
# 19/19 - 2s - loss: 0.6510 - accuracy: 0.7200 - val_loss: 0.4987 - val_accuracy: 0.7900 - lr: 1.0000e-16 - 2s/epoch - 101ms/step
# Epoch 147/150
# 19/19 - 2s - loss: 0.6225 - accuracy: 0.7267 - val_loss: 0.4948 - val_accuracy: 0.7850 - lr: 1.0000e-16 - 2s/epoch - 101ms/step
# Epoch 148/150
# 19/19 - 2s - loss: 0.6397 - accuracy: 0.7433 - val_loss: 0.4931 - val_accuracy: 0.7850 - lr: 1.0000e-16 - 2s/epoch - 101ms/step
# Epoch 149/150
# 19/19 - 2s - loss: 0.6697 - accuracy: 0.7567 - val_loss: 0.4860 - val_accuracy: 0.7850 - lr: 1.0000e-16 - 2s/epoch - 100ms/step
# Epoch 150/150
# 19/19 - 2s - loss: 0.6954 - accuracy: 0.7200 - val_loss: 0.4844 - val_accuracy: 0.7850 - lr: 1.0000e-16 - 2s/epoch - 101ms/step

# %% [markdown]
# <h3>Testing model:</h3>

# %%
testing_data_directory_path = validation_data_directory_path
testing_image_data_generator = ImageDataGenerator(
    rescale=1.0/255
)
testing_data_generator = testing_image_data_generator.flow_from_directory(
    testing_data_directory_path,
    target_size=(image_width, image_height),
    shuffle=False,
    batch_size=batch_size,
    class_mode="categorical",
    color_mode ="grayscale" # FIRST SOLUTION
)
# Out:
# Found 200 images belonging to 5 classes.

# %%
predictions = cnn_model.predict(
    testing_data_generator
)
# Out:
# WARNING:tensorflow:5 out of the last 17 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000029BE32E6F20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 13/13 [==============================] - 0s 22ms/step

# %%
test_loss, test_accuracy = cnn_model.evaluate(
    testing_data_generator, batch_size=batch_size
)

print(f"Test loss: {test_loss}")
print(f"Test accuracy: {test_accuracy}")
# Out:
# 13/13 [==============================] - 0s 23ms/step - loss: 0.4844 - accuracy: 0.7850
# Test loss: 0.4843619167804718
# Test accuracy: 0.7850000262260437

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = class_names[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(testing_data_generator[0][0][idx])
        ax[i, j].axis("off")
        idx+=1
        
plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %% [markdown]
# <h3>Saving model:</h3>

# %%
cnn_model.save_weights("primitives_cnn_model_weights.h5")
cnn_model.save("primitives_cnn_model.keras")

# %% [markdown]
# <h3>Loading and testing model:</h3>

# %%
from keras.models import load_model
from keras.preprocessing.image import load_img

# Loading CNN model.
cnn_model = load_model("primitives_cnn_model.keras")

# Loading square
image = load_img("./validation_data/square/square-bad.png", target_size=(64, 64), color_mode="grayscale")
img = np.array(image)
img = img/255.0
img = img.reshape(1, 64, 64, number_of_channels)

output_label = cnn_model.predict(img)
print(f"Object: {class_names[np.argmax(output_label)]}")
plt.imshow(image)
plt.title("Grayscaled image of square")
plt.show()

# Loading square
image = load_img("./validation_data/circle/circle-bad.png", target_size=(64, 64), color_mode="grayscale")
img = np.array(image)
img = img/255.0
img = img.reshape(1, 64, 64, number_of_channels)

output_label = cnn_model.predict(img)
print(output_label)
print(np.max(output_label))
print(f"Object: {class_names[np.argmax(output_label)]}")
plt.imshow(image)
plt.title("Grayscaled image of circle")
plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000024470A9FEC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 114ms/step
# Object: square
# 1/1 [==============================] - 0s 21ms/step
# [[0.7259388  0.03068426 0.00409908 0.08147756 0.15780035]]
# 0.7259388
# Object: circle
